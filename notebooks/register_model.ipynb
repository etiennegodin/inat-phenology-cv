# %%
import json
from pytorch_pipeline.register import register_model

# %%
path = "/home/etienne/projects/inat-phenology-cv/data/dowloaded_checkpoints"
run_id = "0b44b39e76c6434089ee099baa0681c6"

# %%
register_model(run_id=run_id, checkpoint_path=path, model_name= 'test', device_type="cpu")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 register_model(run_id=run_id, checkpoint_path=path, model_name= 'cv_pheno_bioclip2', device_type="cpu")
#
# File ~/projects/inat-phenology-cv/src/pytorch_pipeline/register.py:27, in register_model(run_id, checkpoint_path, model_name, model_params, device_type)
#      18 def register_model(
#      19     run_id: str,
#      20     checkpoint_path: str,
#    (...)
#      24
#      25 ):
#      26     device = torch.device(device_type)
# ---> 27     checkpoint = Checkpoint.from_file(
#      28         checkpoint_path=checkpoint_path, run_id=run_id, model_params=model_params
#      29     )
#      30     print(checkpoint)
#      31     try:
#      32         # Re-open the finished run context to safely package and upload the model flavor
#
# File ~/projects/inat-phenology-cv/src/pytorch_pipeline/train/persistence.py:73, in Checkpoint.from_file(cls, checkpoint_path, run_id, model, model_params, optimizer)
#      71 if model_params is None:
#      72     if "model_params" in checkpoint_dict:
# ---> 73         model_params = ModelParams(**checkpoint_dict["model_params"])
#      74     else:
#      75         raise ValueError(
#      76             "No model params provided and in checkpoint file - "
#      77             "Can't re-instanciate model to load state dict"
#      78         )
#
# TypeError: ModelParams.__init__() got an unexpected keyword argument 'last_blocks'
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
