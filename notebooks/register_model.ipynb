# %%
import json
from pytorch_pipeline.register import register_model

# %%
path = "/home/etienne/projects/inat-phenology-cv/data/dowloaded_checkpoints"
run_id = "22d7715be4b94959a630b6c68be8c0be"

# %%
register_model(run_id=run_id, checkpoint_path=path, model_name= 'cv_pheno_bioclip2')
# Out:
# ---------------------------------------------------------------------------
# OutOfMemoryError                          Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 register_model(run_id=run_id, checkpoint_path=path, model_name= 'cv_pheno_bioclip2')
#
# File ~/projects/inat-phenology-cv/src/pytorch_pipeline/register.py:23, in register_model(run_id, checkpoint_path, model_name, model_params)
#      17 def register_model(
#      18     run_id: str,
#      19     checkpoint_path: str,
#      20     model_name: str = "my_cool_model",
#      21     model_params: ModelParams | dict | None = None,
#      22 ):
# ---> 23     checkpoint = Checkpoint.from_file(
#      24         checkpoint_path=checkpoint_path, run_id=run_id, model_params=model_params
#      25     )
#      26     try:
#      27         # Re-open the finished run context to safely package and upload the model flavor
#      28         with mlflow.start_run(run_id=run_id):
# ...

# %%
# Legacy without model params in checkpoint
configs_path = '/home/etienne/projects/inat-phenology-cv/data/_temp/configs.json'
with open(configs_path, 'r') as f:
    configs = json.load(f)
model_params = configs.get('model_params', {})
from pprint import pprint
pprint(model_params)
# Out:
# {'attention_dropout_prob': 0.0,
#  'attention_neurons': 128,
#  'backbone': 'bioclip',
#  'gated': True,
#  'head_dropout_prob': 0.5,
#  'head_neurons': 256,
#  'head_outputs': 1,
#  'last_blocks': 1}
