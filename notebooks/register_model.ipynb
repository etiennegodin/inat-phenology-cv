# %%
import json
from pytorch_pipeline.register import register_model

# %%
path = "/home/etienne/projects/inat-phenology-cv/data/dowloaded_checkpoints"
run_id = "0b44b39e76c6434089ee099baa0681c6"

# %%
register_model(run_id=run_id, checkpoint_path=path, model_name= 'test', device_type="cpu")
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Checkpoint(model=PhenologyModel(
#   (backbone): BioClip2Backbone(
#     (encoder): VisionTransformer(
#       (conv1): Conv2d(3, 1024, kernel_size=(14, 14), stride=(14, 14), bias=False)
#       (patch_dropout): Identity()
#       (ln_pre): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#       (transformer): Transformer(
#         (resblocks): ModuleList(
#           (0-23): 24 x ResidualAttentionBlock(
#             (ln_1): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#             (attn): MultiheadAttention(
#               (out_proj): NonDynamicallyQuantizableLinear(in_features=1024, out_features=1024, bias=True)
#             )
#             (ls_1): Identity()
#             (ln_2): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#             (mlp): Sequential(
#               (c_fc): Linear(in_features=1024, out_features=4096, bias=True)
#               (gelu): GELU(approximate='none')
#               (c_proj): Linear(in_features=4096, out_features=1024, bias=True)
#             )
#             (ls_2): Identity()
#           )
#         )
#       )
#       (ln_post): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#     )
#   )
#   (branches): ModuleList(
#     (0-2): 3 x AttentionBranch(
#       (attention): GatedAttentionPooling(
#         (V): Linear(in_features=768, out_features=128, bias=True)
#         (U): Linear(in_features=768, out_features=128, bias=True)
#         (w): Linear(in_features=128, out_features=1, bias=True)
#         (d): Dropout(p=0.0, inplace=False)
#       )
#       (head): ClassifierHead(
#         (V): Linear(in_features=768, out_features=256, bias=True)
#         (r): ReLU()
#         (d): Dropout(p=0.5, inplace=False)
#         (w): Linear(in_features=256, out_features=1, bias=True)
#       )
#     )
#   )
# ), optimizer=None, eval_metrics=EpochMetrics(roc_auc_macro=0.5939797654297001, pr_auc_macro=0.34987466595492517, pr_norm_excess_macro=0.1125876649334125, f1_macro_best=0.44008957620084077, f1_macro_05=0.1127199128133271, f1_micro_05=0.21906202723146748, f1_weighted_05=0.080218758397951, exact_match_ratio=0.05396290050590219, hamming_loss=0.483605021547686, val_loss=1.0135832667350768, roc_auc={'Flowering': 0.7141104950162478, 'Fruiting': 0.5351436092283419, 'Flower_Budding': 0.5326851920445107}, pr_auc={'Flowering': 0.622815387003779, 'Fruiting': 0.21005583768639663, 'Flower_Budding': 0.21675277317459968}, pr_norm_excess={'Flowering': 0.3025432451992956, 'Fruiting': 0.018580988553108007, 'Flower_Budding': 0.016638761047833888}, best_thresh={'Flowering': 0.48999999999999994, 'Fruiting': 0.48999999999999994, 'Flower_Budding': 0.05}, best_f1={'Flowering': 0.6500815660685155, 'Fruiting': 0.33202742409402547, 'Flower_Budding': 0.3381597384399813}, best_prec={'Flowering': 0.4874617737003058, 'Fruiting': 0.2, 'Flower_Budding': 0.2034851039910062}, best_recall={'Flowering': 0.9755201958384333, 'Fruiting': 0.9769452449567724, 'Flower_Budding': 1.0}, f1_05={'Flowering': 0.0, 'Fruiting': 0.0, 'Flower_Budding': 0.3381597384399813}, precision_05={'Flowering': 0.0, 'Fruiting': 0.0, 'Flower_Budding': 0.2034851039910062}, recall_05={'Flowering': 0.0, 'Fruiting': 0.0, 'Flower_Budding': 1.0}, support_pos={'Flowering': 817, 'Fruiting': 347, 'Flower_Budding': 362}, support_neg={'Flowering': 962, 'Fruiting': 1432, 'Flower_Budding': 1417}, prefix='val'))
# 2026/09/14 12:19:45 WARNING mlflow.pytorch: Saving pytorch model by Pickle or CloudPickle format requires exercising caution because these formats rely on Python's object serialization mechanism, which can execute arbitrary code during deserialization. The recommended safe alternative is to set `serialization_format` to 'pt2' to save the PyTorch model using the safe graph model format.
# 2026/09/14 12:20:02 WARNING mlflow.utils.environment: Encountered an unexpected error while inferring pip requirements (model URI: /tmp/tmp4cojrrpn/model/data, flavor: pytorch). Fall back to return ['torch==2.5.1', 'cloudpickle==3.1.2']. Set logging level to DEBUG to see the full traceback.
# Registered model 'test' already exists. Creating a new version of this model...
# 2026/09/14 12:20:09 INFO mlflow.store.model_registry.abstract_store: Waiting up to 300 seconds for model version to finish creation. Model name: test, version 3
# Created version '3' of model 'test'.
# 🏃 View run dashing-roo-955 at: http://localhost:5000/#/experiments/6/runs/0b44b39e76c6434089ee099baa0681c6
# 🧪 View experiment at: http://localhost:5000/#/experiments/6
# Successfully converted .pth and registered it to run 0b44b39e76c6434089ee099baa0681c6
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
