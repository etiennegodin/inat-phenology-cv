# %%
import json
from pytorch_pipeline.register import register_model

# %%
path = "/home/etienne/projects/inat-phenology-cv/data/checkpoints"
path = "/home/etienne/projects/inat-phenology-cv/data/dowloaded_checkpoints"
run_id = "044dc6087f59478fa956f8213269567f"
configs_path = '/home/etienne/projects/inat-phenology-cv/data/_temp/configs.json'

# %%
# Legacy without model params in checkpoint
with open(configs_path, 'r') as f:
    configs = json.load(f)
model_params = configs.get('model_params', {})
from pprint import pprint
pprint(model_params)
# Out:
# {'attention_dropout_prob': 0.0,
#  'attention_neurons': 128,
#  'backbone': 'bioclip',
#  'gated': True,
#  'head_dropout_prob': 0.5,
#  'head_neurons': 256,
#  'head_outputs': 1,
#  'last_blocks': 1}

# %%
register_model(run_id=run_id, checkpoint_path=path, model_name= 'cv_pheno_inat')
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Running on cuda
# 2026/09/03 17:40:53 WARNING mlflow.pytorch: Saving pytorch model by Pickle or CloudPickle format requires exercising caution because these formats rely on Python's object serialization mechanism, which can execute arbitrary code during deserialization. The recommended safe alternative is to set `serialization_format` to 'pt2' to save the PyTorch model using the safe graph model format.
# Successfully registered model 'cv_pheno_inat'.
# 2026/09/03 17:41:18 INFO mlflow.store.model_registry.abstract_store: Waiting up to 300 seconds for model version to finish creation. Model name: cv_pheno_inat, version 1
# Created version '1' of model 'cv_pheno_inat'.
# 🏃 View run adventurous-bee-168 at: http://localhost:5000/#/experiments/5/runs/044dc6087f59478fa956f8213269567f
# 🧪 View experiment at: http://localhost:5000/#/experiments/5
# Successfully converted .pth and registered it to run 044dc6087f59478fa956f8213269567f
