# %%
import json
from pytorch_pipeline.review import review_misclassifications

# %%
path = "/home/etienne/Downloads/report (1).json"

# %%
with open(path, 'r') as file:
    report = json.load(file)

# %%
review_misclassifications(report=report, db_path= "data/cv_raw.duckdb", image_dir= "/home/etienne/projects/inat-phenology-cv/data/images" )
# Out:
# ...
# {'Flowering': {'fp': [{'obs_id': 12813888,
#     'weights': [1.0],
#     'prob': 0.2529,
#     'target': 0,
#     'threshold': 0.05,
#     'paths': ['/home/etienne/projects/inat-phenology-cv/data/images/18582831.jpg']},
#    {'obs_id': 196441575,
#     'weights': [1.0],
#     'prob': 0.263,
#     'target': 0,
#     'threshold': 0.05,
#     'paths': ['/home/etienne/projects/inat-phenology-cv/data/images/345853501.jpg']},
#    {'obs_id': 218989483,
#     'weights': [0.019019324332475662,
#      0.09034965932369232,
#      0.04013212025165558,
#      0.02143268659710884,
#      0.020328203216195107,
#      0.02323843538761139,
#      0.0672534704208374,
#      0.016599534079432487,
#      0.03859105333685875,
#      0.021125955507159233,
#      0.016049152240157127,
#      0.01903649792075157,
#      0.04984000325202942,
#      0.04091925919055939,
#      0.016084598377346992,
#      0.019019324332475662,
#      0.09034965932369232,
#      0.04013212025165558,
# ...
